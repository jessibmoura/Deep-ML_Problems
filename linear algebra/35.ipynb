# %% [markdown]
# ![image.png](attachment:image.png)

# %%
import numpy as np
x = np.array([1, 2, 3])

# %%
def make_diagonal(x):
	n = len(x)
	matrix = np.zeros([n,n])
	for i in range(n):
		for j in range(n):
			if i == j:
				matrix[i][j] = x[i]
	return matrix

# %%
make_diagonal(x)
# Out:
# array([[1., 0., 0.],
#        [0., 2., 0.],
#        [0., 0., 3.]])
